# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats
# %matplotlib inline

# %%
df = pd.read_csv('oec.csv')
print(len(df))
df = df[df['ListsPlanetIsOn'] != 'Retracted planet candidate']
Me = .00315 #Earth's mass in Jupiter mass units
# Out:
# 3584

# %%
sns.set(style='darkgrid')
df.head()
# Out:
#   PlanetIdentifier  TypeFlag  PlanetaryMassJpt  RadiusJpt  PeriodDays  \
# 0      HD 143761 b         0            1.0450        NaN   39.845800
# 1      HD 143761 c         0            0.0790        NaN  102.540000
# 2      KOI-1843.03         0            0.0014      0.054    0.176891
# 3      KOI-1843.01         0               NaN      0.114    4.194525
# 4      KOI-1843.02         0               NaN      0.071    6.356006
#
#    SemiMajorAxisAU  Eccentricity  PeriastronDeg  LongitudeDeg  \
# 0           0.2196         0.037          270.6           NaN
# 1           0.4123         0.050          190.0           NaN
# 2           0.0048           NaN            NaN           NaN
# 3           0.0390           NaN            NaN           NaN
# 4           0.0520           NaN            NaN           NaN
#
#    AscendingNodeDeg        ...          LastUpdated  RightAscension  \
# 0               NaN        ...             16/07/11        16 01 03
# ...

# %% [markdown]
# <H1>Drill 1: One Variable, Plotted 4 ways</H1>
# <H3>Variable: Exoplanet Mass</H3>

# %%
df = df[df['PlanetaryMassJpt'] < 10] #For the sake of pretty plots
data = df.PlanetaryMassJpt.dropna()

# %%
plt.plot(data.sort_values().reset_index().PlanetaryMassJpt);
plt.title('Exoplanets Ranked by Mass');
plt.ylabel('Mass (Jupiter Mass)');
plt.xlabel('Exoplanets Ranked by Mass (Ascending)');
#plt.yscale('log')

# %% [markdown]
# Pros: We get an idea about the continuity of our data.
#
# Cons: Not very descriptive.

# %%
plt.hist(data, bins=40);
plt.title('Exoplanet Mass Distribution');
plt.xlabel('Mass (Jupiter Masses)');
plt.ylabel('Number of Exoplanets');
plt.axvline(x=1, linestyle='dotted', label='1 jupiter mass', color='r');
plt.xlim(0, 10);
plt.legend();

# %% [markdown]
# Pros: We can see the distribution of planets by mass presented clearly.
# It's clear that a huge number of planets are in the 0-.25 Mj range.
#
# Cons: Not super exciting or revealing.

# %%
plot = sns.distplot(data, kde=True, rug=True, bins=40);
plot.set_title('Exoplanet Mass Distribution');
plot.set_xlabel('Mass (Jupiter Mass)');
plot.set_ylabel('Number of Exoplanets');
plot.set_xlim(0, 10)
plt.axvline(x=1, linestyle='dotted', label='1 jupiter mass', color='r');

# %% [markdown]
# Pros: Similar to the histogram with more information.
#
# Cons: The kde may be misleading, especially because the curve extends into a negative x range.

# %%
plt.boxplot(data);
plt.title('Exoplanet Mass');
plt.xticks([1], ['Exoplanets']);
plt.ylabel('Mass (Jupiter Mass)');

# %% [markdown]
# Pros: We can see the concentration of planets on the small side by comparing the size of the top and bottom whiskers.
#
#
# Cons: It's hard to see the "smoothness" of the distribution this way.

# %%
g = sns.kdeplot(data, legend=False)
g.set_title('Exoplanet Mass Distribution');
g.set_xlabel('Mass (Jupiter Mass)');
g.set_ylabel('Proportion of Exoplanets');
g.set_xlim(0, 10);

# %% [markdown]
# Pros: We get an idea about the distribution f our data
# Cons: KDE is just a model, so the data itself isn't presented in this plot.

# %% [markdown]
# <H1>Drill 2: Two Variables, Plotted 3 ways</H1>
# <H3>Variables: Exoplanet Mass vs. Radius</H3>

# %%
mass = df.PlanetaryMassJpt
radius = df.RadiusJpt

# %%
plot = sns.jointplot(mass, radius);
plt.subplots_adjust(top=.9);
plot.fig.suptitle('Exoplanet Mass vs Radius');
plot.set_axis_labels('Mass (Jupiter Mass)', 'Radius (Jupiter Radius)');

# %% [markdown]
# Pros: We can see the relationship and how "noisy" the relationship is.
# The pearson coefficient tells is the correlation is not strong.
#
# Cons: There are two major clusters, and those are easier to spot in other types of plots.

# %%
plot = sns.jointplot(mass, radius, kind="kde");
plt.subplots_adjust(top=.9);
plot.fig.suptitle('Kernel Density Estimate(KDE): Exoplanet Mass Vs. Radius');
plot.set_axis_labels('Mass (Jupiter Mass)', 'Radius (Jupiter Radius)');

# %% [markdown]
# Pros: The two major clusters are easy to see.
#
# Cons: This is just a model. An important flaw is the fact that there are some negative values, which doesn't make sense.

# %%
new_df = df[df['PlanetaryMassJpt'].notnull()]
new_df = new_df[new_df['RadiusJpt'].notnull()] #The coming plot does not like null values.


sns.kdeplot(new_df.PlanetaryMassJpt, new_df.RadiusJpt);
plt.scatter(new_df.PlanetaryMassJpt, new_df.RadiusJpt);
plt.title('Exoplanet Mass vs. Radius');
plt.xlabel('Mass (Jupiter Mass)');
plt.ylabel('Radius (Jupiter Radius)');
plt.xlim(-.25, 10);
plt.ylim(-.1, 2.5);

# %% [markdown]
# Pros: You can see the two clusters and all the points outside of that area.
#
# Cons: Again, the KDE goes into the negative values.

# %% [markdown]
# <H1>Drill 3: One Continuous Variable, One Categorical, Plotted 6 Ways</H1>
# <H3>Continuous Variable: Exoplanet Mass</H3>
# <H3>Categorical Variable: List Planet is On</H3>

# %%
def categorize(df_in):
    df_out = df_in
    df_out['Category'] = ''
    for row in df_in.index:
        if 'Controversial' in df_in['ListsPlanetIsOn'][row]:
            df_out.set_value(row, 'Category', 'Controversial')
        elif 'Confirmed' in df_in['ListsPlanetIsOn'][row]:
            df_out.set_value(row, 'Category', 'Confirmed')
        else:
            df_out.set_value(row, 'Category', 'Solar System')
    return df_out

def binary(df_in):
    df_out = df_in
    df_out['Binary'] = ''
    for row in df_in.index:
        if 'binary' in df_in['ListsPlanetIsOn'][row]:
            df_out.set_value(row, 'Binary', 'Binary Star System')
        elif 'binary' not in df_in['ListsPlanetIsOn'][row]:
            df_out.set_value(row, 'Binary', 'Single Star System')
        else:
            raise Exception('Cannot parse value: "{}"'.format(df_in['ListsPlanetIsOn'][row]))
    return df_out

# %%
df_cat = categorize(df)
df_cat = binary(df_cat)

# %%
plot = sns.stripplot(x='Category', y='PlanetaryMassJpt', hue='Binary', data=df_cat, jitter=True);
plot.set_title('Exoplanet Mass by Category');
plot.set_ylabel('Mass (Jupiter Mass)');
plot.set_xlabel('Category');

# %% [markdown]
# Pros: Able to see distributions, binary system content and distribution, and the weight of each category.
#
# Cons: Lots of overlap even with "jitter" option.

# %%
plot = sns.swarmplot(x='Category', y='PlanetaryMassJpt', hue='Binary', data=df_cat);
plot.set_title('Exoplanet Mass by Category');
plot.set_ylabel('Mass (Jupiter Mass)');
plot.set_xlabel('Category');

# %% [markdown]
# Pros: Same as strip plot but with more clarity
#
# Cons: Still some overlap in big groups. Also, this plot took a long time to load.

# %%
plot = sns.boxplot(x='Category', y='PlanetaryMassJpt', hue='Binary', data=df_cat);
plot.set_title('Exoplanet Mass by Category');
plot.set_ylabel('Mass (Jupiter Mass)');

# %% [markdown]
# Pros: The differences in means and the tendency for binaries is more visible.
#
# Cons: The fact that there are many more single star data points is less apparent. In fact, an uninformed glance might think there are more binary points.

# %%
plot = sns.violinplot(x='Category', y='PlanetaryMassJpt', hue='Binary', data=df_cat);

# %% [markdown]
# Pros: We can see the distributions and means in each group
#
# Cons: Again, we can't see the relative quantity of each (the fact that there are far fewer binary system planets).

# %%
sns.violinplot(x='Category', y='PlanetaryMassJpt', hue='Binary', data=df_cat, split=True);

# %% [markdown]
# Pros: The split plot makes it clearer that there is more spread in the binary planets than single star system.
#
# Cons: The solar system is a little awkward without a binary counterpart. Also, we can't see the difference in means between binary and single star systems.

# %%
sns.barplot(x='Category', y='PlanetaryMassJpt', hue='Binary', data=df_cat);

# %% [markdown]
# Pros: We can see the variance in the controversial category is a lot higher than the confirmed. Also that the mean mass of the binary points is higher than that of the single star points.
#
# Cons: Again, the fact that there are many more points from single star systems is not visible.
